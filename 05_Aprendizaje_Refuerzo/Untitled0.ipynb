# %%
# !pip install tk

# %%
import os
from google.colab import drive, files

# %%
# Montaje del drive
drive.mount('/content/drive', force_remount=True)
os.chdir('/content/drive/MyDrive/datos/p4cm4n')
os.chdir('/content/drive/MyDrive/datos/p4cm4n/Reinforcement')
# Out:
# Mounted at /content/drive

# %%
# !python pacman.py -p PacmanQAgent -x 10000 -n 10010 -l mediumGrid -a epsilon=0.05,alpha=0.45,gamma=0.85 -q
# Out:
# Beginning 10000 episodes of Training
# Reinforcement Learning Status:
# 	Completed 100 out of 10000 training episodes
# 	Average Rewards over all training: -502.83
# 	Average Rewards for last 100 episodes: -502.83
# 	Episode took 1.33 seconds
# Reinforcement Learning Status:
# 	Completed 200 out of 10000 training episodes
# 	Average Rewards over all training: -484.25
# 	Average Rewards for last 100 episodes: -465.68
# 	Episode took 1.31 seconds
# Reinforcement Learning Status:
# 	Completed 300 out of 10000 training episodes
# 	Average Rewards over all training: -478.42
# 	Average Rewards for last 100 episodes: -466.76
# 	Episode took 1.50 seconds
# Reinforcement Learning Status:
# 	Completed 400 out of 10000 training episodes
# 	Average Rewards over all training: -476.14
# 	Average Rewards for last 100 episodes: -469.31
# 	Episode took 1.54 seconds
# Reinforcement Learning Status:
# 	Completed 500 out of 10000 training episodes
# 	Average Rewards over all training: -478.15
# ...
